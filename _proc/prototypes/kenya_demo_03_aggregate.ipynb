# %% [raw]
# ---
# output-file: kenya_demo_03_aggregate.html
# title: 'Part 3: Joining Fishnet to the Ward geometries'
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ---
# skip_showdoc: true
# ---
