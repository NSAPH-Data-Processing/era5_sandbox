# %% [markdown]
# ---
# title: "Demo: How to Create Pipelines with `pytask`"
# ---
#
# ## task_data_preparation
#
# > Data preparation task for `pytask` demo
#
# In this notebook, we are demonstrating how to convert our snakemake workflow into a `pytask` workflow. We use the basic tutorial to demonstrate this, but continue
# to use nbdev for development of functions in notebooks.
#
# `pytask` is a task management system that allows you to define tasks and their dependencies, similar to `Snakemake`. It is particularly useful for data science workflows.
#
# There are a number of reasons to use `pytask` over `snakemake`:
# - **Pythonic**: `pytask` is designed to be purely Pythonic by default, allowing you to write tasks and entire pipelines as Python functions.
# - **Flexibility**: `pytask` allows you to define tasks and their dependencies in a more flexible way, using Python functions and decorators, as opposed to orchestrating numerous scripts.
# - **Integration**: `pytask` integrates well with other Python libraries, such as `nbdev` here, or `hydra` configurations if you need, allowing you to use your existing code, notebooks, or configs in your workflows.
# - **Parallelism**: `pytask` supports parallel execution of tasks with `pytask-parallel`, which can speed up your workflows significantly, especially for data processing tasks.
#
# We'll use nbdev to define the task functions, and then export them to the `src` directory. `pytask` is then invoked at the command line to run the tasks.

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This demo task is taken from the tutorial at [pytask documentation](https://pytask-dev.readthedocs.io/en/stable/tutorials/write_a_task.html). At minimum, you need your package to contain the following in a config.py file:
#
# ```md
# my_project
# │
# ├───.pytask
# │
# ├───bld
# │   └────...
# │
# ├───src
# │   └───my_project
# │       ├────__init__.py
# │       ├────config.py
# │       └────...
# │
# └───pyproject.toml
# ```
#
# ```python
# #contents of `era5_sandbox.config` module
# from pathlib import Path
#
#
# SRC = Path(__file__).parent.resolve()
# BLD = SRC.joinpath("..", "..", "bld").resolve()
# ```
#
# Additionally, your pyproject.toml file should contain the following at minimum:
#
# ```toml
# [tool.pytask.ini_options]
# paths = ["src/era5_sandbox"]
# ```
#
# The former tells Python where to find the source code and build directory for `pytask` objects and shims, while the latter tells `pytask` where to find the task definitions and dependency DAG.

# %% [markdown]
# ### Defining Tasks
#
# To define a task, simply use the `task_` prefix in the function name (or, if you are familiar and comfortable  with decorators, use `@pytask.mark.task`). Be verbose and expressive in your use of type hints to specify the input and output data, so that `pytask` can automatically detect and handle the dependencies between tasks.
#
# ### Defining Tracked Outputs
#
# To define something as a tracked output, you can annotate the input of the task with `Annotated[Path, Product]`, where `Product` is imported from `pytask`. This tells `pytask` that this is a product of the task and should be saved in the build directory.
#
# In this example, we're generating random data into a data frame and saving the object as a pickle in the `bld` directory (`bld` is the default build directory for `pytask`'s intermediate data). To get that directory, we use the `BLD` variable from the `era5_sandbox.config` module as above. This module itself could also be generated using `nbdev` if you want to keep your configuration in notebooks.
#
# Using `nbdev`, we can also include all of the bells and whistles of function documentation.

# %%
#| echo: false
#| output: asis
show_doc(task_create_random_data)
# Out:
# ---
#
# [source](https://github.com/TinasheMTapera/era5_sandbox/blob/main/era5_sandbox/task_data_preparation.py#L21){target="_blank" style="float:right; font-size:smaller"}
#
# ### task_create_random_data
#
# >      task_create_random_data (seed:typing.Annotated[int,42], path_to_data:typi
# >                               ng.Annotated[pathlib.Path,ProductType()]=Path('/
# >                               net/rcstorenfs02/ifs/rc_labs/dominici_lab/lab/da
# >                               ta_processing/csph-era5_sandbox/bld/data.pkl'))
#
# *Create a random data set and save it as a pickle file. Return the path to the saved file.*
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | seed | Annotated |  | Default seed for reproducibility |
# | path_to_data | Annotated | /net/rcstorenfs02/ifs/rc_labs/dominici_lab/lab/data_processing/csph-era5_sandbox/bld/data.pkl | Path to the object in the build directory |
# | **Returns** | **None** |  |  |

# %% [markdown]
# We can test the function directly in the notebook:

# %%
task_create_random_data(42)

# %% [markdown]
# Once this module and function are exported with `nbdev_export`, the functions are in a python package. We can then use the command line to look at the registered tasks:

# %%
#| eval: false

pytask collect
# Out:
#   Cell In[1], line 4
#     pytask collect
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# Let's add another task in the same module. This task plots the data we generated. To link the previous task to this one as a dependency, we can list the output of the previous task as an input to this one. This way, `pytask` will know that it needs to run the first task before this one.

# %%
#| echo: false
#| output: asis
show_doc(task_plot_data)
# Out:
# ---
#
# [source](https://github.com/TinasheMTapera/era5_sandbox/blob/main/era5_sandbox/task_data_preparation.py#L40){target="_blank" style="float:right; font-size:smaller"}
#
# ### task_plot_data
#
# >      task_plot_data (path_to_data:typing.Annotated[pathlib.Path,Path('/net/rcs
# >                      torenfs02/ifs/rc_labs/dominici_lab/lab/data_processing/cs
# >                      ph-era5_sandbox/bld/data.pkl')], path_to_plot:typing.Anno
# >                      tated[pathlib.Path,ProductType()]=Path('/net/rcstorenfs02
# >                      /ifs/rc_labs/dominici_lab/lab/data_processing/csph-
# >                      era5_sandbox/bld/plot.png'))
#
# *Plot the data from the pickle file and save the plot. Note that this task:
#     1. depends on the data.pkl file created by the previous task,
#     2. does not return any value, but saves a plot to the build directory. So the side effect of the task is what we are interested in here (though this is probably bad practice).*
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | path_to_data | Annotated |  | Path to the data file created by the previous task |
# | path_to_plot | Annotated | /net/rcstorenfs02/ifs/rc_labs/dominici_lab/lab/data_processing/csph-era5_sandbox/bld/plot.png | Path to the build directory for the plot |
# | **Returns** | **None** |  |  |

# %% [markdown]
# We now have a DAG of tasks that `pytask` can execute. To see the tasks, we can use the command line to create a pygraphviz graph of the tasks:
#
# ```bash
# pytask dag
# ```
#
# The DAG is saved as a pdf file, and you can view it using any viewer. Now, to run the pipeline, just invoke `pytask` at the command line:
#
# ```bash
# pytask
# ```
#
# In Jupyter or iPython, you can interact with the task outputs directly:

# %%
#| eval: false
# list all the files in the build directory
for file in os.listdir(BLD):
    print(file)
# Out:
# 2019_12_madagascar.nc
# 2013_7_nepal.nc
# 2009_9_nepal.nc
# 2023_10_nepal.nc
# 2022_11_nepal.nc
# 2012_3_madagascar.nc
# 2019_6_madagascar.nc
# 2024_12_nepal_night_swvl1_min.parquet.parquet
# 2022_09_nepal_night_swvl1_max.parquet
# 2019_01_madagascar_night_swvl1_max.parquet
# 2023_3_madagascar.nc
# 2024_9_madagascar.nc
# 2016_1_nepal.nc
# 2012_12_nepal.nc
# 2019_02_madagascar_day_t2m_max.parquet
# 2017_7_madagascar.nc
# 2023_6_madagascar.nc
# 2022_5_nepal.nc
# 2019_2_madagascar.nc
# 2009_5_madagascar.nc
# 2019_06_nepal_night_swvl1_min.parquet
# 2021_3_madagascar.nc
# 2019_06_madagascar_night_swvl1_min.parquet
# 2023_7_nepal.nc
# 2023_11_madagascar.nc
# 2017_4_nepal.nc
# 2024_6_nepal.nc
# 2012_5_madagascar.nc
# 2015_01_madagascar.nc
# 2024_5_nepal_night_swvl1_max.parquet
# 2019_08_madagascar_day_swvl1_max.parquet
# 2020_5_nepal.nc
# 2022_10_madagascar.nc
# 2011_11_madagascar.nc
# 2023_12_madagascar.nc
# 2014_9_nepal.nc
# 2018_5_madagascar.nc
# 2015_6_madagascar.nc
# 2023_4_nepal.nc
# 2010_1_madagascar.nc
# 2020_06_nepal.nc
# 2016_8_madagascar.nc
# 2013_3_madagascar.nc
# 2012_07_nepal.nc
# 2020_6_madagascar.nc
# 2019_1_nepal.nc
# 2014_8_nepal.nc
# 2015_4_madagascar.nc
# 2013_11_madagascar.nc
# 2015_01_madagascar_day_tp_sum.parquet
# 2019_08_madagascar_day_swvl1_mean.parquet
# 2014_6_nepal.nc
# 2024_5_madagascar.nc
# 2013_5_nepal.nc
# 2012_05_nepal_night_t2m_max.parquet
# 2019_7_nepal.nc
# 2017_09_madagascar_day_swvl1_max.parquet
# 2023_04_madagascar.nc
# 2010_09_nepal.nc
# 2012_3_nepal.nc
# 2019_08_madagascar_day_d2m_max.parquet
# 2010_10_nepal.nc
# 2022_12_nepal.nc
# 2019_05_madagascar_day_d2m_mean.parquet
# 2014_4_madagascar.nc
# 2011_5_madagascar.nc
# 2024_05_madagascar_night_swvl1_max.parquet
# 2014_03_madagascar_night_swvl1_mean.parquet
# 2011_04_nepal_night_t2m_max.parquet
# 2020_01_madagascar_night_tp_sum.parquet
# 2015_10_madagascar.nc
# 2015_7_nepal.nc
# 2016_7_nepal.nc
# 2009_4_nepal.nc
# 2009_7_nepal.nc
# 2023_3_nepal.nc
# 2019_04_madagascar.nc
# 2010_9_madagascar.nc
# 2016_5_nepal.nc
# 2023_11_nepal.nc
# 2020_4_madagascar.nc
# 2022_5_madagascar.nc
# 2019_06_madagascar_night_swvl1_max.parquet
# 2021_3_nepal.nc
# 2009_2_nepal.nc
# 2024_5_nepal_day_d2m_mean.parquet
# 2014_05_nepal_day_swvl1_min.parquet
# 2022_2_madagascar.nc
# 2021_5_nepal.nc
# 2018_4_nepal.nc
# 2024_4_nepal.nc
# 2012_05_nepal_night_swvl1_max.parquet
# 2021_4_madagascar.nc
# 2021_12_madagascar.nc
# 2012_01_madagascar.nc
# 2012_12_madagascar.nc
# 2009_8_nepal.nc
# 2014_4_nepal.nc
# plot.png
# 2024_05_madagascar_day_t2m_mean.parquet
# 2011_04_nepal.nc
# 2016_2_madagascar.nc
# 2018_11_madagascar_day_swvl1_min.parquet
# 2016_3_nepal.nc
# 2009_8_madagascar.nc
# 2018_8_madagascar.nc
# 2020_10_nepal_night_swvl1_mean.parquet
# 2019_3_madagascar.nc
# 2021_6_madagascar.nc
# 2017_10_nepal.nc
# 2019_02_madagascar_night_d2m_min.parquet
# 2009_7_madagascar.nc
# 2018_10_madagascar_night_swvl1_min.parquet
# 2018_09_madagascar_day_d2m_mean.parquet
# 2012_5_nepal.nc
# 2014_2_madagascar.nc
# 2015_3_nepal.nc
# 2019_08_madagascar_day_d2m_mean.parquet
# 2012_07_nepal_night_swvl1_mean.parquet
# 2014_05_nepal.nc
# 2016_4_nepal.nc
# 2016_03_nepal.nc
# 2024_6_madagascar.nc
# 2015_08_nepal_night_tp_sum.parquet
# 2012_05_nepal_day_t2m_max.parquet
# 2012_05_nepal.nc
# 2022_6_madagascar.nc
# 2019_10_madagascar_night_t2m_mean.parquet
# 2011_07_nepal_night_swvl1_mean.parquet
# 2018_12_nepal.nc
# 2016_6_madagascar.nc
# 2015_08_nepal_night_t2m_mean.parquet
# 2017_7_nepal.nc
# 2021_11_nepal.nc
# 2022_11_madagascar.nc
# 2020_06_nepal_day_tp_sum.parquet
# 2016_08_madagascar.nc
# 2022_9_nepal.nc
# 2019_05_madagascar_night_d2m_max.parquet
# 2018_11_madagascar.nc
# 2024_5_nepal_night_swvl1_mean.parquet
# 2010_09_nepal_night_tp_sum.parquet
# 2019_02_madagascar_night_swvl1_min.parquet
# 2011_12_madagascar_night_swvl1_max.parquet
# 2021_02_madagascar_night_d2m_max.parquet
# 2017_12_nepal.nc
# 2016_8_nepal.nc
# 2011_7_nepal.nc
# 2017_2_madagascar.nc
# 2018_8_nepal.nc
# 2010_5_madagascar.nc
# 2019_8_nepal.nc
# 2019_7_madagascar.nc
# 2016_03_nepal_day_t2m_max.parquet
# 2011_07_nepal.nc
# 2009_3_madagascar.nc
# 2014_05_nepal_day_t2m_max.parquet
# 2016_7_madagascar.nc
# 2020_11_nepal.nc
# 2023_08_nepal_day_swvl1_mean.parquet
# 2023_04_madagascar_night_d2m_mean.parquet
# 2011_04_nepal_day_swvl1_max.parquet
# 2024_5_nepal_day_tp_sum.parquet
# 2020_07_madagascar_night_tp_sum.parquet
# 2009_06_madagascar_day_swvl1_mean.parquet
# 2014_3_nepal.nc
# 2009_06_madagascar_day_d2m_max.parquet
# 2011_8_madagascar.nc
# 2019_12_madagascar_day_d2m_mean.parquet
# 2018_10_nepal.nc
# 2024_3_madagascar.nc
# 2024_5_nepal_night_d2m_max.parquet
# 2024_5_nepal_day_swvl1_mean.parquet
# 2010_3_nepal.nc
# 2013_4_nepal.nc
# data.pkl
# 2020_12_madagascar.nc
# 2011_3_madagascar.nc
# 2022_08_madagascar_day_t2m_mean.parquet
# 2012_4_nepal.nc
# 2011_7_madagascar.nc
# 2013_11_nepal.nc
# 2019_06_nepal_day_tp_sum.parquet
# 2023_2_nepal.nc
# 2018_4_madagascar.nc
# 2013_08_madagascar.nc
# 2014_12_nepal.nc
# 2019_10_madagascar_day_swvl1_min.parquet
# 2015_8_nepal.nc
# 2011_04_nepal_day_swvl1_min.parquet
# 2023_2_madagascar.nc
# 2024_10_madagascar.nc
# 2016_12_nepal.nc
# 2016_6_nepal.nc
# 2017_6_nepal.nc
# 2013_8_madagascar.nc
# 2021_1_madagascar.nc
# 2024_1_nepal.nc
# 2016_09_madagascar.nc
# 2024_03_nepal_day_t2m_max.parquet
# 2019_6_nepal.nc
# 2011_12_madagascar_night_t2m_min.parquet
# 2015_2_nepal.nc
# 2017_10_madagascar.nc
# 2019_10_nepal.nc
# 2023_8_madagascar.nc
# 2018_9_nepal.nc
# 2019_10_madagascar_night_d2m_max.parquet
# 2019_08_madagascar.nc
# 2015_08_nepal_day_d2m_mean.parquet
# 2024_2_madagascar.nc
# 2021_7_nepal.nc
# 2019_11_nepal.nc
# 2019_05_madagascar_night_t2m_min.parquet
# 2021_9_nepal.nc
# 2019_10_madagascar_day_d2m_min.parquet
# 2016_06_nepal_day_swvl1_max.parquet
# 2021_9_madagascar.nc
# 2023_12_nepal.nc
# 2023_05_madagascar_night_d2m_min.parquet
# 2020_9_nepal.nc
# 2018_2_nepal.nc
# 2016_06_nepal.nc
# 2009_11_nepal.nc
# 2015_1_nepal.nc
# 2017_09_madagascar_night_t2m_mean.parquet
# 2020_11_madagascar.nc
# 2014_11_nepal.nc
# 2014_05_nepal_day_swvl1_max.parquet
# 2024_5_nepal_night_t2m_min.parquet
# 2019_06_nepal.nc
# 2024_05_madagascar_day_d2m_mean.parquet
# 2014_7_madagascar.nc
# 2018_10_madagascar_day_tp_sum.parquet
# 2012_9_nepal.nc
# 2019_8_madagascar.nc
# 2024_5_nepal_night_d2m_min.parquet
# 2017_12_madagascar.nc
# 2019_10_madagascar_day_t2m_max.parquet
# 2023_08_nepal.nc
# 2018_1_nepal.nc
# 2009_1_nepal.nc
# 2022_3_nepal.nc
# 2019_08_madagascar_night_t2m_max.parquet
# 2013_4_madagascar.nc
# 2012_1_madagascar.nc
# 2023_10_madagascar.nc
# 2010_01_nepal_night_d2m_min.parquet
# 2016_2_nepal.nc
# 2024_5_nepal_night_d2m_mean.parquet
# 2017_2_nepal.nc
# 2017_9_nepal.nc
# 2017_8_madagascar.nc
# 2010_8_nepal.nc
# 2023_08_nepal_day_t2m_max.parquet
# 2014_10_nepal.nc
# 2024_5_nepal_day_d2m_min.parquet
# 2018_09_madagascar_day_t2m_mean.parquet
# 2015_8_madagascar.nc
# 2022_08_madagascar_night_d2m_min.parquet
# 2011_11_nepal.nc
# 2019_05_madagascar_day_t2m_min.parquet
# 2015_6_nepal.nc
# 2019_06_madagascar_day_d2m_min.parquet
# 2019_04_madagascar_night_t2m_mean.parquet
# 2013_8_nepal.nc
# 2019_02_madagascar_night_tp_sum.parquet
# 2014_1_madagascar.nc
# 2020_6_nepal.nc
# 2018_10_madagascar_day_t2m_mean.parquet
# 2021_10_nepal.nc
# 2020_2_nepal.nc
# 2019_12_madagascar_night_t2m_mean.parquet
# 2015_01_nepal.nc
# 2017_3_nepal.nc
# 2017_9_madagascar.nc
# 2020_7_madagascar.nc
# 2023_7_madagascar.nc
# 2021_2_nepal.nc
# 2022_4_madagascar.nc
# 2017_5_nepal.nc
# 2023_9_nepal.nc
# 2011_1_madagascar.nc
# 2013_12_nepal.nc
# 2013_08_nepal_night_t2m_min.parquet
# 2019_10_madagascar_day_d2m_mean.parquet
# 2014_03_madagascar_day_t2m_mean.parquet
# 2017_11_madagascar.nc
# 2014_7_nepal.nc
# 2022_1_nepal.nc
# 2010_6_nepal.nc
# 2012_2_nepal.nc
# 2019_9_madagascar.nc
# 2022_6_nepal.nc
# 2020_3_nepal.nc
# 2021_02_madagascar_night_swvl1_min.parquet
# 2014_05_nepal_night_swvl1_max.parquet
# 2012_4_madagascar.nc
# 2024_12_nepal.nc
# 2019_01_madagascar.nc
# 2019_02_madagascar_night_t2m_min.parquet
# 2010_4_madagascar.nc
# 2009_10_madagascar.nc
# 2010_12_nepal.nc
# 2016_11_nepal.nc
# 2018_7_nepal.nc
# 2024_3_nepal.nc
# 2014_03_madagascar.nc
# 2019_5_madagascar.nc
# 2021_1_nepal.nc
# 2017_1_madagascar.nc
# 2009_02_nepal.nc
# 2012_05_nepal_night_swvl1_min.parquet
# 2012_9_madagascar.nc
# 2011_6_nepal.nc
# 2022_7_nepal.nc
# 2019_10_madagascar_day_tp_sum.parquet
# 2012_10_nepal.nc
# 2014_3_madagascar.nc
# 2023_1_nepal.nc
# 2014_10_madagascar.nc
# 2009_10_nepal.nc
# 2011_04_nepal_day_t2m_mean.parquet
# 2012_8_nepal.nc
# 2019_2_nepal.nc
# 2015_7_madagascar.nc
# 2015_08_nepal.nc
# 2010_06_madagascar.nc
# 2010_2_nepal.nc
# 2021_02_madagascar.nc
# 2011_9_madagascar.nc
# 2019_3_nepal.nc
# 2017_3_madagascar.nc
# 2019_04_madagascar_day_swvl1_min.parquet
# 2010_7_nepal.nc
# 2013_12_madagascar.nc
# 2022_09_nepal.nc
# 2024_5_nepal_night_t2m_max.parquet
# 2013_08_nepal.nc
# 2020_8_nepal.nc
# 2013_7_madagascar.nc
# 2020_06_nepal_night_swvl1_max.parquet
# 2012_11_nepal.nc
# 2018_11_nepal_night_t2m_min.parquet
# 2023_12_madagascar_day_d2m_max.parquet
# 2016_03_nepal_day_d2m_max.parquet
# 2009_06_madagascar_night_d2m_min.parquet
# 2013_08_madagascar_day_swvl1_max.parquet
# 2020_01_madagascar_night_t2m_max.parquet
# 2024_9_nepal.nc
# 2019_4_madagascar.nc
# 2014_10_nepal_night_t2m_min.parquet
# 2024_5_nepal_night_tp_sum.parquet
# 2013_08_madagascar_night_swvl1_min.parquet
# 2016_5_madagascar.nc
# 2015_01_nepal_night_tp_sum.parquet
# 2016_1_madagascar.nc
# 2023_5_madagascar.nc
# 2019_06_madagascar.nc
# 2013_9_nepal.nc
# 2018_7_madagascar.nc
# 2019_01_madagascar_night_swvl1_min.parquet
# 2018_10_madagascar.nc
# 2013_08_nepal_night_tp_sum.parquet
# 2024_11_madagascar.nc
# 2024_2_nepal.nc
# 2023_1_madagascar.nc
# 2023_9_madagascar.nc
# 2024_5_nepal_day_t2m_min.parquet
# 2020_06_nepal_day_t2m_max.parquet
# 2010_06_madagascar_night_t2m_max.parquet
# 2022_7_madagascar.nc
# 2023_4_madagascar.nc
# 2020_5_madagascar.nc
# 2015_1_madagascar.nc
# 2012_01_madagascar_night_tp_sum.parquet
# 2023_04_madagascar_night_swvl1_mean.parquet
# 2015_11_madagascar.nc
# 2020_3_madagascar.nc
# 2018_09_madagascar_day_t2m_min.parquet
# 2009_4_madagascar.nc
# 2019_05_madagascar_day_tp_sum.parquet
# 2019_10_madagascar.nc
# 2018_10_madagascar_day_swvl1_min.parquet
# 2023_5_nepal.nc
# 2011_5_nepal.nc
# 2015_11_nepal.nc
# 2009_2_madagascar.nc
# 2011_6_madagascar.nc
# 2019_04_madagascar_night_t2m_min.parquet
# 2012_6_nepal.nc
# 2014_03_madagascar_day_swvl1_min.parquet
# 2020_8_madagascar.nc
# 2010_2_madagascar.nc
# 2022_11_nepal_night_d2m_min.parquet
# 2019_02_madagascar_day_d2m_min.parquet
# 2016_3_madagascar.nc
# 2013_10_madagascar.nc
# 2021_11_madagascar.nc
# 2024_11_nepal.nc
# 2011_05_nepal_day_d2m_max.parquet
# 2023_8_nepal.nc
# 2018_6_nepal.nc
# 2014_11_madagascar.nc
# 2018_5_nepal.nc
# 2021_02_madagascar_night_t2m_mean.parquet
# 2020_01_madagascar_day_t2m_max.parquet
# 2024_8_nepal.nc
# 2015_01_nepal_day_swvl1_mean.parquet
# 2011_07_nepal_day_d2m_min.parquet
# 2021_2_madagascar.nc
# 2021_6_nepal.nc
# 2010_3_madagascar.nc
# 2019_02_madagascar.nc
# 2022_08_madagascar.nc
# 2021_8_madagascar.nc
# 2014_12_madagascar.nc
# 2017_1_nepal.nc
# 2011_12_nepal.nc
# 2011_4_nepal.nc
# 2009_06_madagascar_night_d2m_max.parquet
# 2017_09_madagascar.nc
# 2022_11_nepal_night_d2m_mean.parquet
# 2010_6_madagascar.nc
# 2017_05_nepal_day_swvl1_max.parquet
# 2009_3_nepal.nc
# 2017_6_madagascar.nc
# 2013_08_nepal_day_d2m_mean.parquet
# 2013_2_nepal.nc
# 2015_10_nepal.nc
# 2021_8_nepal.nc
# 2022_11_nepal_day_swvl1_min.parquet
# 2018_11_nepal_day_swvl1_min.parquet
# 2013_1_nepal.nc
# 2018_11_nepal.nc
# 2021_4_nepal.nc
# 2012_7_nepal.nc
# 2019_10_madagascar_night_swvl1_max.parquet
# 2014_10_nepal_day_d2m_max.parquet
# 2011_12_madagascar_day_t2m_max.parquet
# 2019_12_nepal.nc
# 2019_01_madagascar_day_t2m_mean.parquet
# 2012_8_madagascar.nc
# 2015_9_madagascar.nc
# 2014_6_madagascar.nc
# 2011_12_madagascar_day_swvl1_min.parquet
# 2010_4_nepal.nc
# 2022_9_madagascar.nc
# 2024_05_madagascar_day_swvl1_max.parquet
# 2019_9_nepal.nc
# 2022_12_madagascar.nc
# 2024_10_nepal.nc
# 2012_01_madagascar_day_swvl1_min.parquet
# 2016_09_madagascar_night_swvl1_max.parquet
# 2024_1_madagascar.nc
# 2016_06_nepal_night_swvl1_max.parquet
# 2016_11_madagascar.nc
# 2011_2_nepal.nc
# 2023_6_nepal.nc
# 2016_03_nepal_night_t2m_max.parquet
# 2015_3_madagascar.nc
# 2024_05_madagascar.nc
# 2017_8_nepal.nc
# 2014_8_madagascar.nc
# 2009_06_madagascar.nc
# 2017_11_nepal.nc
# 2024_5_nepal_night_t2m_mean.parquet
# 2016_09_madagascar_night_tp_sum.parquet
# 2018_12_madagascar.nc
# 2022_09_nepal_day_d2m_max.parquet
# 2023_05_madagascar_day_t2m_min.parquet
# 2014_2_nepal.nc
# 2011_8_nepal.nc
# 2017_01_nepal.nc
# 2015_2_madagascar.nc
# 2018_1_madagascar.nc
# 2011_4_madagascar.nc
# 2010_10_madagascar.nc
# 2012_1_nepal.nc
# 2017_09_madagascar_day_tp_sum.parquet
# 2010_8_madagascar.nc
# 2009_1_madagascar.nc
# 2018_9_madagascar.nc
# 2010_1_nepal.nc
# 2011_10_madagascar.nc
# 2014_1_nepal.nc
# 2020_1_nepal.nc
# 2014_03_madagascar_night_tp_sum.parquet
# 2022_1_madagascar.nc
# 2019_08_madagascar_day_swvl1_min.parquet
# 2024_5_nepal_day_t2m_max.parquet
# 2023_05_madagascar.nc
# 2023_05_madagascar_night_t2m_mean.parquet
# 2011_05_nepal.nc
# 2022_4_nepal.nc
# 2012_10_madagascar.nc
# 2011_05_nepal_night_d2m_max.parquet
# 2019_08_madagascar_day_d2m_min.parquet
# 2015_12_madagascar.nc
# 2020_07_madagascar.nc
# 2020_07_madagascar_day_t2m_mean.parquet
# 2011_3_nepal.nc
# 2023_08_nepal_night_d2m_mean.parquet
# 2011_2_madagascar.nc
# 2024_8_madagascar.nc
# 2019_05_madagascar_night_swvl1_max.parquet
# 2016_10_nepal.nc
# 2024_5_nepal.nc
# 2014_5_nepal.nc
# 2020_7_nepal.nc
# 2019_10_madagascar_night_d2m_mean.parquet
# 2019_09_madagascar.nc
# 2010_12_madagascar.nc
# 2020_10_madagascar.nc
# 2013_5_madagascar.nc
# 2024_03_nepal.nc
# 2018_6_madagascar.nc
# 2019_08_madagascar_day_tp_sum.parquet
# 2024_5_nepal_day_swvl1_max.parquet
# 2011_03_nepal.nc
# 2022_3_madagascar.nc
# 2020_1_madagascar.nc
# 2019_05_madagascar.nc
# 2024_4_madagascar.nc
# 2019_06_madagascar_day_tp_sum.parquet
# 2020_4_nepal.nc
# 2019_06_nepal_day_swvl1_max.parquet
# 2017_4_madagascar.nc
# 2015_12_nepal.nc
# 2024_5_nepal_day_d2m_max.parquet
# 2016_4_madagascar.nc
# 2019_06_madagascar_day_t2m_mean.parquet
# 2017_09_madagascar_day_swvl1_min.parquet
# 2020_12_nepal.nc
# 2015_5_madagascar.nc
# 2011_07_nepal_night_d2m_max.parquet
# 2017_5_madagascar.nc
# 2009_12_madagascar.nc
# 2020_01_madagascar.nc
# 2009_12_nepal.nc
# 2020_01_madagascar_day_swvl1_mean.parquet
# 2018_11_nepal_day_d2m_mean.parquet
# 2013_1_madagascar.nc
# 2014_5_madagascar.nc
# 2013_9_madagascar.nc
# 2020_12_nepal_night_d2m_min.parquet
# 2010_01_nepal.nc
# 2018_09_madagascar.nc
# 2010_5_nepal.nc
# 2019_1_madagascar.nc
# 2011_04_nepal_day_d2m_max.parquet
# 2019_06_madagascar_day_t2m_min.parquet
# 2009_5_nepal.nc
# 2011_10_nepal.nc
# 2010_11_nepal.nc
# 2015_9_nepal.nc
# 2024_5_nepal_day_t2m_mean.parquet
# 2024_03_nepal_day_t2m_min.parquet
# 2012_7_madagascar.nc
# 2019_04_madagascar_day_swvl1_max.parquet
# 2021_12_nepal.nc
# 2010_7_madagascar.nc
# 2024_7_madagascar.nc
# 2013_6_nepal.nc
# 2013_10_nepal.nc
# 2019_01_madagascar_night_t2m_min.parquet
# 2011_1_nepal.nc
# 2023_08_nepal_night_swvl1_min.parquet
# 2019_11_madagascar.nc
# 2016_9_madagascar.nc
# 2012_05_nepal_day_tp_sum.parquet
# 2009_6_madagascar.nc
# 2023_07_nepal.nc
# 2024_7_nepal.nc
# 2009_06_madagascar_night_t2m_max.parquet
# 2013_2_madagascar.nc
# 2020_10_nepal.nc
# 2022_2_nepal.nc
# 2013_08_nepal_night_t2m_mean.parquet
# 2016_12_madagascar.nc
# 2014_9_madagascar.nc
# 2024_5_nepal_day_swvl1_min.parquet
# 2024_05_madagascar_day_swvl1_mean.parquet
# 2012_11_madagascar.nc
# 2013_08_nepal_night_d2m_mean.parquet
# 2015_4_nepal.nc
# 2014_05_nepal_day_d2m_mean.parquet
# 2021_10_madagascar.nc
# 2023_07_nepal_day_t2m_min.parquet
# 2011_12_madagascar.nc
# 2020_9_madagascar.nc
# 2016_06_nepal_night_d2m_max.parquet
# 2009_11_madagascar.nc
# 2022_09_nepal_day_t2m_mean.parquet
# 2022_10_nepal.nc
# 2018_3_nepal.nc
# 2010_11_madagascar.nc
# 2016_03_nepal_day_t2m_mean.parquet
# 2012_6_madagascar.nc
# 2012_05_nepal_day_swvl1_max.parquet
# 2019_4_nepal.nc
# 2016_10_madagascar.nc
# 2021_12_nepal_day_t2m_max.parquet
# 2010_9_nepal.nc
# 2012_07_nepal_night_t2m_max.parquet
# 2009_6_nepal.nc
# 2017_05_nepal.nc
# 2013_6_madagascar.nc
# 2014_05_nepal_night_d2m_mean.parquet
# 2016_9_nepal.nc
# 2024_12_madagascar.nc
# 2012_2_madagascar.nc
# 2011_05_nepal_day_t2m_max.parquet
# 2018_09_madagascar_night_t2m_max.parquet
# 2011_9_nepal.nc
# 2019_10_madagascar_day_d2m_max.parquet
# 2013_3_nepal.nc
# 2022_8_madagascar.nc
# 2018_2_madagascar.nc
# 2021_7_madagascar.nc
# 2020_2_madagascar.nc
# 2015_5_nepal.nc
# 2022_8_nepal.nc
# 2014_03_madagascar_day_d2m_min.parquet
# 2021_5_madagascar.nc
# 2024_5_nepal_night_swvl1_min.parquet
# 2019_5_nepal.nc
# 2009_9_madagascar.nc
# 2018_3_madagascar.nc

# %% [markdown]
# We can use these to build subsequent tasks later.
#
# ## More Complex Tasks & The Data Catalog
#
# As we define more complex tasks, we can use the `pytask` data catalog to manage the inputs and outputs of our tasks. The data catalog allows us to imperatively name the data and their formats, making it easier to manage the data flow in our tasks. Importantly, we can define the data pythonically, which allows us to use the full power of Python to manipulate and transform our data. This is particularly more useful than snakemake's approach, which requires you to define the data in a more static way using paths and a separate pseudo-language.
#
# The content of the `era5_sandbox.config` module can be extended to include a data catalog:
#
# ```python
# from pathlib import Path
# from pytask import DataCatalog, Product
#
# SRC = Path(__file__).parent.resolve()
# BLD = SRC.joinpath("..", "..", "bld").resolve()
#
# demo_catalog = DataCatalog()
# ```
#
# With just this definition, we're now able to refer directly to data by name in our tasks, and `pytask` will handle the paths and formats for us. This allows us to focus on the logic of our tasks rather than the details of data management.
#
# :::{.callout-note}
# This is a major advantage of `pytask` over `snakemake`, as it allows you to define the data in a more flexible and Pythonic way, while still maintaining the benefits of a task management system. It is a similar approach to building pipelines in R with targets, which allows you to define the data in a more flexible way.
# :::
#
# Let's create a task that modifies the data frame by adding a new column. This task will depend on the previous task's output, and we will use the data catalog to define the input and output data.

# %%
#| echo: false
#| output: asis
show_doc(task_add_one)
# Out:
# ---
#
# [source](https://github.com/TinasheMTapera/era5_sandbox/blob/main/era5_sandbox/task_data_preparation.py#L59){target="_blank" style="float:right; font-size:smaller"}
#
# ### task_add_one
#
# >      task_add_one (path_to_data:typing.Annotated[pathlib.Path,Path('/net/rcsto
# >                    renfs02/ifs/rc_labs/dominici_lab/lab/data_processing/csph-
# >                    era5_sandbox/bld/data.pkl')], node:typing.Annotated[_pytask
# >                    .nodes.PickleNode,ProductType()]=PickleNode(path=Path('/net
# >                    /rcstorenfs02/ifs/rc_labs/dominici_lab/lab/data_processing/
# >                    csph-era5_sandbox/.pytask/data_catalogs/default/1eef510d81e
# >                    ea49161cd821b318aa999e630bdd292b093aa9a9319e9f282b984.pkl')
# >                    , name='mydata', attributes={'catalog_name': 'default'},
# >                    serializer=<built-in function dump>, deserializer=<built-in
# >                    function load>))
#
# *Add one to the 'y' column of the data frame and save it as a new pickle file.*
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | path_to_data | Annotated |  | Path to the data file created by the previous task |
# | node | Annotated | PickleNode(path=Path('/net/rcstorenfs02/ifs/rc_labs/dominici_lab/lab/data_processing/csph-era5_sandbox/.pytask/data_catalogs/default/1eef510d81eea49161cd821b318aa999e630bdd292b093aa9a9319e9f282b984.pkl'), name='mydata', attributes={'catalog_name': 'default'}, serializer=<built-in function dump>, deserializer=<built-in function load>) |  |
# | **Returns** | **None** |  |  |

# %% [markdown]
# In this function, we've defined that the task relies on the output of the first task being there, the `data.pkl` file. But importantly, we've also defined our product as a `node` from the `PickleNode` module. This will allow `pytask` to handle the serialization and deserialization of the data frame automatically, so we don't have to worry about the details of how the data is stored. We create the datacatalog in our config file, and then tell this task to create a Node in that catalog called `mydata`. Whatever we save with the `node.save()` method will be saved in the build directory, but more importantly _will be indexed and hashed by `pytask`_. This means that if the data changes, `pytask` will know to rerun the task.
#
# To make this even more pythonic, we can modify the format of our task function so that the return type annotator is used as a node in the data catalog. This allows us to define the output of the task as a `PickleNode`, which will automatically handle the serialization and deserialization of the data frame.
#
# :::{.callout-note}
# This is another trick I'm deriving from {targets}. By formatting tasks as pure functions where inputs are parameters and targets are return type annotations, we can define the output of the task as a `PickleNode`, which will automatically handle the serialization and deserialization of the data frame. This again allows us to focus on the logic of our tasks rather than the details of data management.
# :::
#
# So below, we're directly accessing the `data_catalog` to get the `mydata` node, and then modifying it by adding a new column. It _feels_ like we are doing this in place, such as in an iPython session, because we are allowing `pytask` to handle the serialization of the file on disk for us.

# %%
#| echo: false
#| output: asis
show_doc(task_add_another_column)
# Out:
# ---
#
# [source](https://github.com/TinasheMTapera/era5_sandbox/blob/main/era5_sandbox/task_data_preparation.py#L72){target="_blank" style="float:right; font-size:smaller"}
#
# ### task_add_another_column
#
# >      task_add_another_column (df:typing.Annotated[pandas.core.frame.DataFrame,
# >                               PickleNode(path=Path('/net/rcstorenfs02/ifs/rc_l
# >                               abs/dominici_lab/lab/data_processing/csph-era5_s
# >                               andbox/.pytask/data_catalogs/default/1eef510d81e
# >                               ea49161cd821b318aa999e630bdd292b093aa9a9319e9f28
# >                               2b984.pkl'),name='mydata',attributes={'catalog_n
# >                               ame':'default'},serializer=<built-
# >                               infunctiondump>,deserializer=<built-
# >                               infunctionload>)])
#
# *Add another column to the data frame stored in the PickleNode.*
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | df | Annotated | which object in the catalog to fetch from the catalog with node.load() |
# | **Returns** | **Annotated** | **which object in the catalog to save the return value to** |

# %% [markdown]
# To test this interactively, we'd have to import the data catalog's object

# %%
df = demo_catalog["mydata"].load()  # load the data frame from the PickleNode
result = task_add_another_column(df)  # call the task function with the loaded data frame

# %%
result
# Out:
#              x          y          z           w
# 0     8.047171  16.035059  17.035059  273.158174
# 1    -5.399841 -11.528969 -10.528969  121.388159
# 2    12.504512  24.594551  25.594551  629.486482
# 3    14.405647  29.445205  30.445205  896.465285
# 4   -14.510352 -29.017710 -28.017710  813.009811
# ..         ...        ...        ...         ...
# 995   8.527202  17.446414  18.446414  321.823783
# 996  12.668229  25.640295  26.640295  683.065015
# 997   6.211779  12.332019  13.332019  164.410711
# 998   6.307642  12.084462  13.084462  158.118682
# 999  13.237531  28.689215  29.689215  851.760287
#
# [1000 rows x 4 columns]

# %% [markdown]
# Now that we know it will work, we can invoke pytask:

# %%
#| eval: false

pytask
# Out:
# UsageError: Line magic function `%%sh` not found.
# Traceback (most recent call last):
#
#   File "/n/home03/ttapera/.conda/envs/era5_sandbox/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3549, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-dafc120439b3>", line 2, in <module>
#     get_ipython().run_line_magic('%sh', '')
#
#   File "/n/home03/ttapera/.conda/envs/era5_sandbox/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2461, in run_line_magic
#     raise UsageError(etpl % (magic_name, extra))
#
# IPython.core.error.UsageError: Line magic function `%%sh` not found.

# %% [markdown]
# Notice that the outputs are cached and not recomputed unless the inputs change. This is a key feature of `pytask` and other DAGs, allowing you to efficiently manage your data processing tasks without unnecessary recomputation.
#
# ## Conclusion
#
# The takeaway here is that with `pytask`, you can define pure functions that take inputs and return outputs, and build a DAG of tasks that can be executed in a flexible and efficient way. This allows you to focus on the logic of your tasks rather than the details of data management, while still maintaining the benefits of a task management system. The key elements are:
#
# - **Task annotation**: You define your tasks by creating pure functions that take inputs and return outputs, and use decorators or naming conventions to mark them as "tasks" in a dag
# - **Input and output annotation**: You define the inputs and outputs of your tasksusing type hints, and allow `pytask` to automatically detect and handle the dependencies between tasks.
# - **Data catalog**: You define your data in a Pythonic object in your config called `data_catalog`. As you iteratively develop your DAG, you add objects to the data catalog, which are called nodes. As long as a node is a pythonic object and has a pickle method, `pytask` will handle the serialization and deserialization of the data for you.
